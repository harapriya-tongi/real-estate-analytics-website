# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type             society      sector  price  price_per_sqft  \
# 0          flat      dlf the primus  sector 82a   3.50         13430.0
# 1          flat       sbr apartment     manesar   0.68          4456.0
# 2          flat        malibu towne   sector 47   2.40         10000.0
# 3          flat  godrej nature plus   sector 33   1.25          9025.0
# 4          flat     pareena mi casa   sector 68   0.92          7389.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2606.0                   Carpet area: 2606 (242.11 sq.m.)        5
# 1  1526.0                 Built Up area: 1526 (141.77 sq.m.)        3
# 2  2400.0                   Carpet area: 2400 (222.97 sq.m.)        3
# 3  1385.0  Built Up area: 1385 (128.67 sq.m.)Carpet area:...        2
# 4  1245.0             Super Built up area 1245(115.66 sq.m.)        2
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0       5.0     3.0      14.0  North-East      Relatively New
# 1       3.0     3.0       2.0         NaN      Moderately Old
# 2       3.0     NaN       0.0        West      Moderately Old
# 3       2.0     3.0      17.0         NaN           Undefined
# 4       2.0     3.0       5.0        West  Under Construction
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN       2606.0           1             0
# 1                  NaN         1526.0          NaN           0             0
# 2                  NaN            NaN       2400.0           0             0
# 3                  NaN         1385.0       1000.0           0             0
# 4               1245.0            NaN          NaN           0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                1            49
# 1           0           0       0                0             0
# 2           0           0       0                2            22
# 3           0           0       0                0            56
# 4           0           0       1                0            50

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'] , y=df['price'] , estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'] , y=df['price'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'] , y=df['built_up_area'] , estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier

df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'] , y=df['built_up_area'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price-per_sqft

# %%
sns.barplot(x=df['property_type'] , y=df['price_per_sqft'] , estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'] , y=df['price_per_sqft'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers

df[df['price_per_sqft'] > 100000][['property_type' , 'society' , 'sector' , 'price' , 'price_per_sqft' , 'area' , 'areaWithType' , 'super_built_up_area' , 'built_up_area' , 'carpet_area' , ]]
# Out:
#      property_type                      society     sector  price  \
# 891          house     unitech uniworld resorts  sector 33  10.00
# 1007         house     unitech uniworld resorts  sector 33   9.50
# 1067         house                dlf the grove  sector 54   5.70
# 1150         house       dlf city plots phase 2  sector 25  10.00
# 1203         house                  independent  sector 24  10.00
# 1218         house       dlf city plots phase 2  sector 25  10.50
# 1634         house       unitech deerwood chase  sector 50   8.45
# 1669         house            vatika india next  sector 82   7.00
# 1750         house           vipul tatvam villa  sector 48   7.25
# 1769         house          huda plot sector 38  sector 38   4.30
# 1785          flat           ambience caitriona  sector 24  14.00
# 1797         house                  independent  sector 28   4.50
# 1848         house                    rk excelo  sector 12   0.60
# 2052         house                  independent  sector 12   3.50
# 2445         house  unitech nirvana birch court  sector 50   7.10
# 2550         house                        ansal  sector 43   1.85
# 2652         house         bhim nagar, sector 6   sector 6   0.85
# 2750         house                  independent  sector 12   6.00
# 2867         house       emaar the palm springs  sector 54  24.00
# 2905         house                  independent  sector 57   8.00
# 2971         house         eros rosewood villas  sector 49   2.75
# 3196         house                   ardee city  sector 52   5.50
# 3328         house                  independent  sector 17   3.50
# 3378         house                  independent  sector 54   3.75
# 3401         house                  independent  sector 23   2.80
# 3405         house                  independent  sector 38   8.00
# 3503         house               uppal southend  sector 49   6.75
# 3744         house                  independent  sector 55   1.45
# 3800         house                  independent   sector 4   0.60
#
#       price_per_sqft   area  \
# 891         181818.0  550.0
# 1007        173992.0  546.0
# 1067        211111.0  270.0
# 1150        400000.0  250.0
# 1203        229885.0  435.0
# 1218        261194.0  402.0
# 1634        235376.0  359.0
# 1669        194444.0  360.0
# 1750        201388.0  360.0
# 1769        245398.0  175.0
# 1785        200000.0  700.0
# 1797        125000.0  360.0
# 1848        120000.0   50.0
# 2052        133079.0  263.0
# 2445        283333.0  251.0
# 2550        308333.0   60.0
# 2652        126865.0   67.0
# 2750        315789.0  190.0
# 2867        600000.0  400.0
# 2905        266666.0  300.0
# 2971        178571.0  154.0
# 3196        183333.0  300.0
# 3328        218750.0  160.0
# 3378        234375.0  160.0
# 3401        161849.0  173.0
# 3405        230547.0  347.0
# 3503        290948.0  232.0
# 3744        241666.0   60.0
# 3800        105263.0   57.0
#
#                                            areaWithType  super_built_up_area  \
# 891                           Plot area 550(51.1 sq.m.)                  NaN
# 1007                         Plot area 546(50.73 sq.m.)                  NaN
# 1067                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 1150                         Plot area 250(23.23 sq.m.)                  NaN
# 1203                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 1218                         Plot area 402(37.35 sq.m.)                  NaN
# 1634                         Plot area 359(33.35 sq.m.)                  NaN
# 1669  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 1750                         Plot area 360(33.45 sq.m.)                  NaN
# 1769  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 1785                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 1797                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 1848  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 2052  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2445                          Plot area 240(22.3 sq.m.)                  NaN
# 2550                           Plot area 60(5.57 sq.m.)                  NaN
# 2652                           Plot area 67(6.22 sq.m.)                  NaN
# 2750  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 2867                         Plot area 400(37.16 sq.m.)                  NaN
# 2905                         Plot area 300(27.87 sq.m.)                  NaN
# 2971  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 3196                         Plot area 300(27.87 sq.m.)                  NaN
# 3328                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 3378                         Plot area 160(14.86 sq.m.)                  NaN
# 3401  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 3405  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 3503                         Plot area 232(21.55 sq.m.)                  NaN
# 3744                           Plot area 60(5.57 sq.m.)                  NaN
# 3800                            Plot area 57(5.3 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 891           550.0          NaN
# 1007          546.0          NaN
# 1067          270.0          NaN
# 1150          250.0          NaN
# 1203            NaN        435.0
# 1218          402.0          NaN
# 1634          359.0          NaN
# 1669         3900.0       3743.0
# 1750          360.0          NaN
# 1769          145.0          NaN
# 1785          700.0          NaN
# 1797          360.0          NaN
# 1848           30.0         15.0
# 2052         4800.0       4400.0
# 2445          240.0          NaN
# 2550           60.0          NaN
# 2652           67.0          NaN
# 2750            NaN       1600.0
# 2867          400.0          NaN
# 2905          300.0          NaN
# 2971            NaN       1650.0
# 3196          300.0          NaN
# 3328          160.0          NaN
# 3378          160.0          NaN
# 3401          160.0        150.0
# 3405          347.0        215.0
# 3503          232.0          NaN
# 3744           60.0          NaN
# 3800           57.0          NaN

# %%
sns.heatmap(pd.crosstab(df['property_type'] , df['bedRoom']))
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='property_type'>

# %%
# Checking outliers

df[df['bedRoom'] >=10]
# Out:
#      property_type                    society     sector  price  \
# 48           house  ganpati heights apartment  sector 13   1.25
# 112          house                independent  sector 40  12.00
# 153          house                independent  sector 25  16.00
# 171          house                independent  sector 54   5.00
# 463          house                independent  sector 25   9.00
# ...            ...                        ...        ...    ...
# 3725         house                independent  sector 56   8.00
# 3738         house                independent  sector 27   8.25
# 3756         house                independent  sector 26  26.00
# 3775         house                   shivpuri   sector 7   2.80
# 3802         house                   shivpuri   sector 7   2.40
#
#       price_per_sqft     area  \
# 48             151.0  82781.0
# 112          38986.0   3078.0
# 153          59259.0   2700.0
# 171          43066.0   1161.0
# 463          28490.0   3159.0
# ...              ...      ...
# 3725          9654.0   8287.0
# 3738         45833.0   1800.0
# 3756         82540.0   3150.0
# 3775         12444.0   2250.0
# 3802          8889.0   2700.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 48                         Plot area 115(7692.86 sq.m.)       10       6.0
# 112                         Plot area 342(285.96 sq.m.)       16      16.0
# 153   Plot area 350(292.64 sq.m.)Built Up area: 325 ...       16      16.0
# 171                         Plot area 129(107.86 sq.m.)       21      21.0
# 463                         Plot area 351(293.48 sq.m.)       10      10.0
# ...                                                 ...      ...       ...
# 3725  Plot area 362(33.63 sq.m.)Built Up area: 8286 ...       10      10.0
# 3738  Plot area 210(175.59 sq.m.)Built Up area: 205 ...       12      12.0
# 3756  Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16      16.0
# 3775                       Plot area 2250(209.03 sq.m.)       10       7.0
# 3802                        Plot area 300(250.84 sq.m.)       10       5.0
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 48         2       3.0  South-East    Old Property                  NaN
# 112       3+       4.0         NaN    New Property                  NaN
# 153       3+       4.0        West    New Property                  NaN
# 171       3+       5.0       North  Relatively New                  NaN
# 463        3       3.0        East    Old Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3725      3+       4.0         NaN  Relatively New                  NaN
# 3738      3+       4.0        East    New Property                  NaN
# 3756      3+       4.0  North-West    New Property                  NaN
# 3775       3       1.0         NaN    Old Property                  NaN
# 3802       3       2.0       North    Old Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 48            115.0          NaN           0             0           0
# 112           342.0          NaN           1             1           1
# 153           325.0        300.0           1             1           1
# 171           129.0          NaN           0             1           0
# 463           351.0          NaN           0             0           0
# ...             ...          ...         ...           ...         ...
# 3725         8286.0          NaN           1             1           0
# 3738          205.0        200.0           0             1           0
# 3756          400.0        350.0           1             1           1
# 3775         2250.0          NaN           1             1           0
# 3802          300.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 48             0       1                0             7
# 112            1       0                2             0
# 153            1       0                1            72
# 171            0       0                1            49
# 463            1       0                2            64
# ...          ...     ...              ...           ...
# 3725           1       0                1           107
# 3738           1       0                2            40
# 3756           1       0                1            72
# 3775           1       1                2             0
# 3802           1       0                0             8
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'] , y=df['floorNum'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'] , y=df['floorNum'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='floorNum'>

# %%
# checking outliers

df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 301          house          godrej meridien  sector 106   5.60
# 695          house              greenopolis   sector 89   0.70
# 709          house           dlf the arbour   sector 63   8.50
# 851          house         suncity township   sector 54   2.00
# 1231         house        suncity avenue 76   sector 76   0.75
# 1489         house      ireo victory valley   sector 67   8.00
# 1851         house      satya the hermitage  sector 103   3.15
# 2056         house              spaze privy   sector 72   3.10
# 2370         house              independent   sector 92   1.80
# 2427         house           ats tourmaline  sector 109   1.87
# 2554         house               ninex city   sector 76   1.75
# 2829         house   vatika the seven lamps   sector 82   1.60
# 3385         house  indiabulls centrum park  sector 103   3.25
# 3748         house              spaze privy   sector 72   3.09
#
#       price_per_sqft    area  \
# 301          14000.0  4000.0
# 695           5397.0  1297.0
# 709          21519.0  3950.0
# 851          30968.0   646.0
# 1231         10067.0   745.0
# 1489         22222.0  3600.0
# 1851          6702.0  4700.0
# 2056          8486.0  3653.0
# 2370          7627.0  2360.0
# 2427          8697.0  2150.0
# 2554          6250.0  2800.0
# 2829          6597.0  2425.0
# 3385          8125.0  4000.0
# 3748          6981.0  4426.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 301                        Plot area 4000(371.61 sq.m.)        5       4.0
# 695                   Built Up area: 1297 (120.5 sq.m.)        2       2.0
# 709                  Built Up area: 3950 (366.97 sq.m.)        4       4.0
# 851   Plot area 60Built Up area: 60 sq.m.Carpet area...        9       9.0
# 1231  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2       2.0
# 1489                        Plot area 400(334.45 sq.m.)        6       7.0
# 1851                 Built Up area: 4700 (436.64 sq.m.)        4       5.0
# 2056                       Plot area 3653(339.37 sq.m.)        5       5.0
# 2370                 Built Up area: 2360 (219.25 sq.m.)        4       5.0
# 2427                 Built Up area: 2150 (199.74 sq.m.)        3       4.0
# 2554                   Carpet area: 2800 (260.13 sq.m.)        4       4.0
# 2829                       Plot area 2425(225.29 sq.m.)        4       4.0
# 3385                       Plot area 4000(371.61 sq.m.)        4       3.0
# 3748  Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5       5.0
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 301       3+      33.0  North-East        New Property                  NaN
# 695        2      14.0  North-East           Undefined                  NaN
# 709       3+      27.0         NaN           Undefined                  NaN
# 851        3      11.0       North      Relatively New                  NaN
# 1231       2      11.0  North-East        New Property                  NaN
# 1489      3+      51.0  North-East      Moderately Old                  NaN
# 1851       0      12.0        East           Undefined                  NaN
# 2056      3+      21.0         NaN      Relatively New                  NaN
# 2370       0      13.0         NaN           Undefined                  NaN
# 2427       0      12.0         NaN           Undefined                  NaN
# 2554       0      14.0         NaN           Undefined                  NaN
# 2829      3+      16.0       North      Moderately Old                  NaN
# 3385      3+      20.0         NaN  Under Construction                  NaN
# 3748      3+      14.0        East      Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 301          4000.0          NaN           1             1           1
# 695          1297.0          NaN           0             0           0
# 709          3950.0          NaN           0             0           0
# 851            60.0         59.0           0             1           0
# 1231          745.0          NaN           0             0           0
# 1489          400.0          NaN           1             1           0
# 1851         4700.0          NaN           0             0           0
# 2056         3653.0          NaN           0             0           0
# 2370         2360.0          NaN           0             0           0
# 2427         2150.0          NaN           0             0           0
# 2554            NaN       2800.0           0             0           0
# 2829         2425.0          NaN           0             1           0
# 3385         4000.0          NaN           0             0           0
# 3748         3653.0       2922.0           0             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 301            1       0                0           151
# 695            0       0                0             0
# 709            0       0                0            61
# 851            0       0                1             7
# 1231           0       0                0            40
# 1489           1       0                2            49
# 1851           0       0                0            61
# 2056           0       0                0             0
# 2370           0       0                0             0
# 2427           0       0                0             0
# 2554           0       0                0             0
# 2829           0       0                0            94
# 3385           0       0                0            51
# 3748           0       0                2            33

# %%
sns.heatmap(pd.crosstab(df['property_type'] , df['agePossession']))
# Out:
# <AxesSubplot:xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))

sns.heatmap(pd.pivot_table(df, index='property_type' , columns='bedRoom' , values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'] , df['furnishing_type']))
# Out:
# <AxesSubplot:xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df, index='property_type' , columns='furnishing_type' , values='price',aggfunc='mean'),annot=True)
# Out:
# <AxesSubplot:xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'] , y=df['luxury_score'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'] , y=df['luxury_score'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='luxury_score'>

# %% [markdown]
# ### sector analysis

# %%
plt.figure(figsize=(15,6))

sns.heatmap(pd.crosstab(df['property_type'] , df['sector'].sort_index()))
# Out:
# <AxesSubplot:xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(df[df['area']<10000]['area'], df['price'], hue=df['bedRoom'])
# Out:
# C:\Users\harap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(df[df['area']<10000]['area'], df['price'], hue=df['agePossession'])
# Out:
# C:\Users\harap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(df[df['area']<10000]['area'], df['price'], hue=df['furnishing_type'].astype('category'))
# Out:
# C:\Users\harap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'] , y=df['price'], estimator=np.median)
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'] , y=df['price'] , estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'] , y=df['area'], estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'] , y=df['price'], estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(df['luxury_score'] , df['price'])
# Out:
# C:\Users\harap\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589826
# bedRoom                0.522925
# servant room           0.400927
# price_per_sqft         0.391251
# pooja room             0.341492
# store room             0.309121
# study room             0.258602
# furnishing_type        0.238668
# luxury_score           0.094775
# built_up_area          0.052254
# area                   0.034720
# others                -0.003525
# carpet_area           -0.011344
# floorNum              -0.094290
# Name: price, dtype: float64
